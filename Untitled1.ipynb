# %%
import math as m
import random as r
import numpy as np

# %%
m = int(input("m?"))
n = int(input("n?"))
print(type(m),type(n))
# Out:
# m?300
# n?300
# <class 'int'> <class 'int'>

# %%
def cal_deviate(x1,y1):
    return max((x1/m-y1/n),(y1/n-x1/m))

# %%
def generate_rand(arr,m,n):
    if arr.count(0) == m:
        return 1
    elif arr.count(1) == n:
        return 0
    else:
        return r.randint(0,1)

# %%
def grid_traverse(n,m):
    x = 0 
    y = 0 
    max_N = m
    max_E = n
    D = [0.0]
    B = [[0,0]]
    A = []
    if(x==n and y==m): return
    for i in range(m+n):
        b = generate_rand(A,m,n)
        A.append(b)
        if b == 0 and max_N!=0:
            y = y + 1
            max_N = max_N - 1
            print("max_N",max_N)
        if b == 1 and max_E!=0:
            x = x + 1
            max_E = max_E - 1
            print("max_E",max_E)
        D.append(cal_deviate(x,y))
        B.append([x,y])
    print(B)
    return np.array(D)

# %%
ans = grid_traverse(n,m)
ans
# Out:
# max_N 299
# max_E 299
# max_E 298
# max_N 298
# max_E 297
# max_N 297
# max_E 296
# max_N 296
# max_E 295
# max_E 294
# max_E 293
# max_N 295
# max_N 294
# max_N 293
# max_E 292
# max_E 291
# max_E 290
# max_E 289
# max_E 288
# max_E 287
# max_E 286
# max_E 285
# max_E 284
# max_N 292
# max_N 291
# max_N 290
# max_E 283
# max_E 282
# max_N 289
# max_E 281
# max_E 280
# max_N 288
# max_N 287
# max_N 286
# max_N 285
# max_N 284
# max_E 279
# max_N 283
# max_E 278
# max_N 282
# max_E 277
# max_N 281
# max_E 276
# max_E 275
# max_E 274
# max_E 273
# max_E 272
# max_N 280
# max_N 279
# max_E 271
# max_N 278
# max_E 270
# max_N 277
# max_E 269
# max_N 276
# max_N 275
# max_N 274
# max_N 273
# max_N 272
# max_N 271
# max_E 268
# max_E 267
# max_E 266
# max_N 270
# max_N 269
# max_E 265
# max_E 264
# max_N 268
# max_N 267
# max_N 266
# max_N 265
# max_E 263
# max_E 262
# max_E 261
# max_E 260
# max_E 259
# max_E 258
# max_E 257
# max_E 256
# max_E 255
# max_N 264
# max_E 254
# max_E 253
# ...

# %%
D1 = np.array(ans)

# %%
(sum(i > 0.6 for i in ans)/len(ans))/(sum(i > 0.2 for i in ans)/len(ans))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in double_scalars
#   """Entry point for launching an IPython kernel.
# nan

# %%
np.mean(ans)
# Out:
# 0.03936772046589019

# %%
len(ans)
# Out:
# 601

# %%
sum(i > 0.6 for i in ans)
# Out:
# 0

# %%
def find_all_paths(graph, start, end, path=[]):
        path = path + [start]
        if start == end:
            return [path]
        if start not in graph:
            return []
        paths = []
        for node in graph[start]:
            if node not in path:
                newpaths = find_all_paths(graph, node, end, path)
                for newpath in newpaths:
                    paths.append(newpath)
        return paths

# %%
graph = {'00': ['01', '02'],
         '02': ['03','04']}

# %%
find_all_paths(graph, '00', '04')
# Out:
# [['00', '02', '04']]

# %%
def graph
# Out:
# '01'
